# %% [markdown]
# # MeCab + Neologdのインストール

# %%
# MeCab＋Comejisyoのセッティング
# install MeCab# insta 
# !apt install aptitude swig
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.996.3

#neologd辞書のインストール
# !git clone --depth 1 https://github.com/neologd/mecab-ipadic-neologd.git
# !echo yes | mecab-ipadic-neologd/bin/install-mecab-ipadic-neologd -n -a

# %%
import MeCab
import subprocess

cmd = 'echo `mecab-config --dicdir`"/mecab-ipadic-neologd"'
path = (subprocess.Popen(cmd, stdout=subprocess.PIPE,
                           shell=True).communicate()[0]).decode('utf-8')

# neologdライブラリの配置場所を表示
print(path)
# Out:
# /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd

# %%
import MeCab
# 辞書の場所を指定してあげる
tagger = MeCab.Tagger("-d /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd")

#ユーザー辞書を使用するときは -u オプションで辞書の場所を指定する
# tagger = MeCab.Tagger("-u /content/drive/MyDrive/pinoko/ComeJisyoUtf8-3.dic")

text = "いつものホットコーヒーを頼んで、週末の作業をする"
result = tagger.parse(text)

# %%
print(result)
# Out:
# いつも	副詞,一般,*,*,*,*,いつも,イツモ,イツモ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ホット	名詞,一般,*,*,*,*,ホット,ホット,ホット
# コーヒー	名詞,一般,*,*,*,*,コーヒー,コーヒー,コーヒー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 頼ん	動詞,自立,*,*,五段・マ行,連用タ接続,頼む,タノン,タノン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 週末	名詞,副詞可能,*,*,*,*,週末,シュウマツ,シューマツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# EOS
